# %%
# Data Processing
import pandas as pd
import numpy as np

# Modelling
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# Tree Visualisation
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz

# %%
cin = pd.read_csv('https://raw.githubusercontent.com/data-to-insight/D2I-Jupyter-Notebook-Tools/refs/heads/main/ml-data%20science%20tutorials/data/CINdetails.csv')
characteristics = pd.read_csv('https://raw.githubusercontent.com/data-to-insight/D2I-Jupyter-Notebook-Tools/refs/heads/main/ml-data%20science%20tutorials/data/ChildCharacteristics.csv')
identifiers = pd.read_csv('https://raw.githubusercontent.com/data-to-insight/D2I-Jupyter-Notebook-Tools/refs/heads/main/ml-data%20science%20tutorials/data/ChildIdentifiers.csv')
identifiers
# Out:
#      Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0             0  RND000215205141  A850728973744        NaN         NaN
# 1             1  RND000824303014  A141396438491        NaN         NaN
# 2             2  RND000750143123  A929946861554        NaN         NaN
# 3             3  RND000909164501  A612330267292        NaN         NaN
# 4             4  RND000382171815  A604459366806        NaN         NaN
# ..          ...              ...            ...        ...         ...
# 327         327  RND000112711501  A465246916125        NaN         NaN
# 328         328  RND000513120794  A540014111973        NaN         NaN
# 329         329  RND000541643134  A549582689058        NaN         NaN
# 330         330  RND000404939452  A889492349196        NaN         NaN
# 331         331  RND000589802835  A877624860226        NaN         NaN
#
#     PersonBirthDate  ExpectedPersonBirthDate  GenderCurrent PersonDeathDate
# 0        2019-12-06                      NaN              1             NaN
# 1        2011-04-27                      NaN              9             NaN
# 2        2017-06-06                      NaN              1             NaN
# 3        2014-10-03                      NaN              0             NaN
# 4        2019-09-25                      NaN              2             NaN
# ..              ...                      ...            ...             ...
# 327      2010-07-07                      NaN              2             NaN
# 328      2018-08-14                      NaN              2             NaN
# 329      2021-12-09                      NaN              1             NaN
# 330      2013-07-23                      NaN              2             NaN
# 331      2021-10-25                      NaN              9             NaN
#
# [332 rows x 9 columns]

# %%
print(cin.info())
print(identifiers.info())
print(characteristics.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        101 non-null    int64
#  1   LAchildID         101 non-null    object
#  2   CINdetailsID      101 non-null    int64
#  3   CINreferralDate   101 non-null    object
#  4   ReferralSource    101 non-null    object
#  5   PrimaryNeedCode   101 non-null    object
#  6   CINclosureDate    63 non-null     object
#  7   ReasonForClosure  63 non-null     object
#  8   DateOfInitialCPC  85 non-null     object
#  9   ReferralNFA       101 non-null    bool
# dtypes: bool(1), int64(2), object(7)
# memory usage: 7.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               332 non-null    int64
#  1   LAchildID                332 non-null    object
#  2   UPN                      332 non-null    object
#  3   FormerUPN                0 non-null      float64
#  4   UPNunknown               0 non-null      float64
#  5   PersonBirthDate          332 non-null    object
#  6   ExpectedPersonBirthDate  0 non-null      float64
#  7   GenderCurrent            332 non-null    int64
#  8   PersonDeathDate          21 non-null     object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 23.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  332 non-null    int64
#  1   LAchildID   332 non-null    object
#  2   Ethnicity   332 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 7.9+ KB
# None

# %%
cin.sort_values('CINreferralDate', inplace=True, ascending=False)
cin.drop_duplicates('LAchildID', inplace=True, keep='first')

cin['CINplan'] = 1

cin
# Out:
#     Unnamed: 0        LAchildID  CINdetailsID CINreferralDate ReferralSource  \
# 36          36  RND000098194912             1      31/08/2012              7
# 89          89  RND000333386932             1      30/12/2019             2A
# 71          71  RND000467290394             1      30/09/2013             5C
# 8            8  RND000471630058             2      30/06/2022              6
# 46          46  RND000789331304             1      30/04/2018              7
# ..         ...              ...           ...             ...            ...
# 65          65  RND000469602476             1      03/07/2016             3C
# 6            6  RND000382171815             1      02/04/2021             2A
# 70          70  RND000235844862             1      01/11/2014             2A
# 55          55  RND000702784676             1      01/09/2017             1A
# 9            9  RND000852873211             1      01/07/2018             1A
#
#    PrimaryNeedCode CINclosureDate ReasonForClosure DateOfInitialCPC  \
# 36              N6     03/03/2014              RC2       21/10/2012
# 89              N7            NaN              NaN       14/02/2020
# 71              N0     05/02/2020              RC7       27/10/2013
# 8               N6            NaN              NaN       12/07/2022
# 46              N4     25/11/2018              RC6       16/07/2018
# ..             ...            ...              ...              ...
# 65              N3            NaN              NaN              NaN
# 6               N3     23/06/2021              RC3       02/04/2021
# 70              N2            NaN              NaN       26/01/2015
# 55              N2            NaN              NaN       27/11/2017
# 9               N9     23/08/2019              RC4       04/09/2018
#
#     ReferralNFA  CINplan
# 36        False        1
# 89        False        1
# 71        False        1
# 8         False        1
# 46        False        1
# ..          ...      ...
# 65        False        1
# 6         False        1
# 70        False        1
# 55        False        1
# 9         False        1
#
# [89 rows x 11 columns]

# %%
df = characteristics.merge(identifiers, how='left', on='LAchildID')
df = df.merge(cin, how='left', on='LAchildID')

# %%
df = characteristics.merge(identifiers, how='left', on='LAchildID')
df = df.merge(cin, how='left', on='LAchildID')

df['Age'] = pd.to_datetime('today') - pd.to_datetime(df['PersonBirthDate'], format='%Y-%m-%d')

df['Age'] = df['Age']/pd.Timedelta(days=365)

cols_to_keep = ['Age', 'Ethnicity', 'GenderCurrent', 'CINplan']

df = df[cols_to_keep]

df
# Out:
#            Age Ethnicity  GenderCurrent  CINplan
# 0     4.834331      WIRT              1      1.0
# 1    13.450770      WROM              9      1.0
# 2     7.335701      AOTH              1      1.0
# 3    10.012414      MWBC              0      1.0
# 4     5.031592      APKN              2      1.0
# ..         ...       ...            ...      ...
# 327  14.256249      WOTH              2      NaN
# 328   6.146660      WROM              2      NaN
# 329   2.823372      BCRB              1      NaN
# 330  11.209674      AIND              2      NaN
# 331   2.946660      WBRI              9      NaN
#
# [332 rows x 4 columns]

# %%
df['CINplan'] = df['CINplan'].fillna(0)

df
# Out:
#            Age Ethnicity  GenderCurrent  CINplan
# 0     4.834331      WIRT              1      1.0
# 1    13.450770      WROM              9      1.0
# 2     7.335701      AOTH              1      1.0
# 3    10.012414      MWBC              0      1.0
# 4     5.031592      APKN              2      1.0
# ..         ...       ...            ...      ...
# 327  14.256249      WOTH              2      0.0
# 328   6.146660      WROM              2      0.0
# 329   2.823372      BCRB              1      0.0
# 330  11.209674      AIND              2      0.0
# 331   2.946660      WBRI              9      0.0
#
# [332 rows x 4 columns]

# %%
gender_dict = {1:'male',
               2:'female',
               0:'other',
               9:'other'}

df['GenderCurrent'] = df['GenderCurrent'].map(gender_dict)

df
# Out:
#            Age Ethnicity GenderCurrent  CINplan
# 0     4.834331      WIRT          male      1.0
# 1    13.450770      WROM         other      1.0
# 2     7.335701      AOTH          male      1.0
# 3    10.012414      MWBC         other      1.0
# 4     5.031592      APKN        female      1.0
# ..         ...       ...           ...      ...
# 327  14.256249      WOTH        female      0.0
# 328   6.146660      WROM        female      0.0
# 329   2.823372      BCRB          male      0.0
# 330  11.209674      AIND        female      0.0
# 331   2.946660      WBRI         other      0.0
#
# [332 rows x 4 columns]

# %%
def ethnic_check(row):
    letter = row[0]
    if letter == 'W':
        return 'white'
    if letter == 'B':
        return 'black'
    if (letter == 'A') | (letter == 'C'):
        return 'asian'
    if letter == 'M':
        return 'Mixed'
    else:
        return 'other'


df['Ethnicity'] = df['Ethnicity'].apply(ethnic_check)

df
# Out:
#            Age Ethnicity GenderCurrent  CINplan
# 0     4.834331     white          male      1.0
# 1    13.450770     white         other      1.0
# 2     7.335701     asian          male      1.0
# 3    10.012414     Mixed         other      1.0
# 4     5.031592     asian        female      1.0
# ..         ...       ...           ...      ...
# 327  14.256249     white        female      0.0
# 328   6.146660     white        female      0.0
# 329   2.823372     black          male      0.0
# 330  11.209674     asian        female      0.0
# 331   2.946660     white         other      0.0
#
# [332 rows x 4 columns]

# %%
df_encoded = pd.get_dummies(df[['GenderCurrent', 'Ethnicity']])

full_df = df[['Age', 'CINplan']].merge(df_encoded, how='left', left_index=True, right_index=True)

full_df
# Out:
#            Age  CINplan  GenderCurrent_female  GenderCurrent_male  \
# 0     4.834331      1.0                 False                True
# 1    13.450770      1.0                 False               False
# 2     7.335701      1.0                 False                True
# 3    10.012414      1.0                 False               False
# 4     5.031592      1.0                  True               False
# ..         ...      ...                   ...                 ...
# 327  14.256249      0.0                  True               False
# 328   6.146660      0.0                  True               False
# 329   2.823372      0.0                 False                True
# 330  11.209674      0.0                  True               False
# 331   2.946660      0.0                 False               False
#
#      GenderCurrent_other  Ethnicity_Mixed  Ethnicity_asian  Ethnicity_black  \
# 0                  False            False            False            False
# 1                   True            False            False            False
# 2                  False            False             True            False
# 3                   True             True            False            False
# 4                  False            False             True            False
# ..                   ...              ...              ...              ...
# 327                False            False            False            False
# 328                False            False            False            False
# 329                False            False            False             True
# 330                False            False             True            False
# 331                 True            False            False            False
#
#      Ethnicity_other  Ethnicity_white
# 0              False             True
# 1              False             True
# 2              False            False
# 3              False            False
# 4              False            False
# ..               ...              ...
# 327            False             True
# 328            False             True
# 329            False            False
# 330            False            False
# 331            False             True
#
# [332 rows x 10 columns]

# %%
# split data into features and label
X = full_df.drop('CINplan', axis=1)
y = full_df['CINplan']

# split data into train/test splits
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# instantiate object for model
rf = RandomForestClassifier()

# fit model
rf.fit(X_train, y_train)

# make predictions
y_pred = rf.predict(X_test)

# check accuracy
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6417910447761194

# %%
tree = rf.estimators_[0]

dot_data = export_graphviz(tree,
                           feature_names=X_train.columns,
                           filled=True,
                           max_depth=3)
graph = graphviz.Source(dot_data)
display(graph)

# %%
for i in range(3):
    tree = rf.estimators_[i]
 
    dot_data = export_graphviz(tree,
                            feature_names=X_train.columns,
                            filled=True,
                            max_depth=3)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
new_rf = RandomForestClassifier()

rand_search = RandomizedSearchCV(new_rf,
                                 param_distributions={'n_estimators':randint(50,500),
                                                      'max_depth':randint(1,20)},
                                                      n_iter=10)

rand_search.fit(X_train, y_train)

print(rand_search.best_params_)

best_rf = rand_search.best_estimator_
# Out:
# {'max_depth': 3, 'n_estimators': 160}

# %%
y_pred = best_rf.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot()

# %%
feature_importance_df = pd.DataFrame({'feature importance': rf.feature_importances_,
                                      'feature':X_train.columns})\
                                      .set_index('feature')

feature_importance_df.plot.bar()
# Out:
# <Axes: xlabel='feature'>
